# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/asus/OneDrive/Desktop/US_Accidents.csv")
data.head()
# Out:
#           ID  Severity        Start_Time          End_Time  Start_Lat  \
# 0  A-2716600         3  08-02-2016 00:37  08-02-2016 06:37   40.10891
# 1  A-2716601         2  08-02-2016 05:56  08-02-2016 11:56   39.86542
# 2  A-2716602         2  08-02-2016 06:15  08-02-2016 12:15   39.10266
# 3  A-2716603         2  08-02-2016 06:15  08-02-2016 12:15   39.10148
# 4  A-2716604         2  08-02-2016 06:51  08-02-2016 12:51   41.06213
#
#    Start_Lng   End_Lat   End_Lng  Distance(mi)  \
# 0  -83.09286  40.11206 -83.03187         3.230
# 1  -84.06280  39.86501 -84.04873         0.747
# 2  -84.52468  39.10209 -84.52396         0.055
# 3  -84.52341  39.09841 -84.52241         0.219
# 4  -81.53784  41.06217 -81.53547         0.123
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# 2                   At I-71/US-50/Exit 1 - Accident.  ...       False   False
# 3                   At I-71/US-50/Exit 1 - Accident.  ...       False   False
# 4                    At Dart Ave/Exit 21 - Accident.  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False          Night
# 1  False           False          False        False          Night
# 2  False           False          False        False          Night
# 3  False           False          False        False          Night
# 4  False           False          False        False          Night
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                 Night
# 2          Night             Night                   Day
# 3          Night             Night                   Day
# 4          Night               Day                   Day
#
# [5 rows x 47 columns]

# %%
data.shape
# Out:
# (1048575, 47)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1048575 non-null  object
#  1   Severity               1048575 non-null  int64
#  2   Start_Time             1048575 non-null  object
#  3   End_Time               1048575 non-null  object
#  4   Start_Lat              1048575 non-null  float64
#  5   Start_Lng              1048575 non-null  float64
#  6   End_Lat                1048575 non-null  float64
#  7   End_Lng                1048575 non-null  float64
#  8   Distance(mi)           1048575 non-null  float64
#  9   Description            1048575 non-null  object
#  10  Number                 360065 non-null   float64
#  11  Street                 1048575 non-null  object
#  12  Side                   1048575 non-null  object
#  13  City                   1048506 non-null  object
#  14  County                 1048575 non-null  object
#  15  State                  1048575 non-null  object
#  16  Zipcode                1048086 non-null  object
#  17  Country                1048575 non-null  object
#  18  Timezone               1047421 non-null  object
#  19  Airport_Code           1045917 non-null  object
#  20  Weather_Timestamp      1026460 non-null  object
#  21  Temperature(F)         1017832 non-null  float64
#  22  Wind_Chill(F)          813974 non-null   float64
#  23  Humidity(%)            1015803 non-null  float64
#  24  Pressure(in)           1023115 non-null  float64
#  25  Visibility(mi)         1017760 non-null  float64
#  26  Wind_Direction         1017532 non-null  object
#  27  Wind_Speed(mph)        980665 non-null   float64
#  28  Precipitation(in)      789334 non-null   float64
#  29  Weather_Condition      1018315 non-null  object
#  30  Amenity                1048575 non-null  bool
#  31  Bump                   1048575 non-null  bool
#  32  Crossing               1048575 non-null  bool
#  33  Give_Way               1048575 non-null  bool
#  34  Junction               1048575 non-null  bool
#  35  No_Exit                1048575 non-null  bool
#  36  Railway                1048575 non-null  bool
#  37  Roundabout             1048575 non-null  bool
#  38  Station                1048575 non-null  bool
#  39  Stop                   1048575 non-null  bool
#  40  Traffic_Calming        1048575 non-null  bool
#  41  Traffic_Signal         1048575 non-null  bool
#  42  Turning_Loop           1048575 non-null  bool
#  43  Sunrise_Sunset         1048506 non-null  object
#  44  Civil_Twilight         1048506 non-null  object
#  45  Nautical_Twilight      1048506 non-null  object
#  46  Astronomical_Twilight  1048506 non-null  object
# dtypes: bool(13), float64(13), int64(1), object(20)
# memory usage: 285.0+ MB

# %%
data.drop(columns = ['ID','Description','County','Zipcode','Timezone','Airport_Code','Pressure(in)',
                     'Weather_Timestamp','Sunrise_Sunset','Wind_Chill(F)','Humidity(%)',
                     'Wind_Direction','Civil_Twilight','Nautical_Twilight','Astronomical_Twilight'], inplace=True)

# %%
data.head()
# Out:
#    Severity        Start_Time          End_Time  Start_Lat  Start_Lng  \
# 0         3  08-02-2016 00:37  08-02-2016 06:37   40.10891  -83.09286
# 1         2  08-02-2016 05:56  08-02-2016 11:56   39.86542  -84.06280
# 2         2  08-02-2016 06:15  08-02-2016 12:15   39.10266  -84.52468
# 3         2  08-02-2016 06:15  08-02-2016 12:15   39.10148  -84.52341
# 4         2  08-02-2016 06:51  08-02-2016 12:51   41.06213  -81.53784
#
#     End_Lat   End_Lng  Distance(mi)  Number       Street  ... Give_Way  \
# 0  40.11206 -83.03187         3.230     NaN  Outerbelt E  ...    False
# 1  39.86501 -84.04873         0.747     NaN       I-70 E  ...    False
# 2  39.10209 -84.52396         0.055     NaN       I-75 S  ...    False
# 3  39.09841 -84.52241         0.219     NaN      US-50 E  ...    False
# 4  41.06217 -81.53547         0.123     NaN       I-77 N  ...    False
#
#   Junction No_Exit Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 0    False   False   False       False    False  False            False
# 1    False   False   False       False    False  False            False
# 2     True   False   False       False    False  False            False
# 3     True   False   False       False    False  False            False
# 4    False   False   False       False    False  False            False
#
#   Traffic_Signal  Turning_Loop
# 0          False         False
# 1          False         False
# 2          False         False
# 3          False         False
# 4          False         False
#
# [5 rows x 32 columns]

# %%
data.isna().sum()
# Out:
# Severity                  0
# Start_Time                0
# End_Time                  0
# Start_Lat                 0
# Start_Lng                 0
# End_Lat                   0
# End_Lng                   0
# Distance(mi)              0
# Number               688510
# Street                    0
# Side                      0
# City                     69
# State                     0
# Country                   0
# Temperature(F)        30743
# Visibility(mi)        30815
# Wind_Speed(mph)       67910
# Precipitation(in)    259241
# Weather_Condition     30260
# Amenity                   0
# Bump                      0
# Crossing                  0
# Give_Way                  0
# Junction                  0
# No_Exit                   0
# Railway                   0
# Roundabout                0
# Station                   0
# Stop                      0
# Traffic_Calming           0
# Traffic_Signal            0
# Turning_Loop              0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# Severity             0
# Start_Time           0
# End_Time             0
# Start_Lat            0
# Start_Lng            0
# End_Lat              0
# End_Lng              0
# Distance(mi)         0
# Number               0
# Street               0
# Side                 0
# City                 0
# State                0
# Country              0
# Temperature(F)       0
# Visibility(mi)       0
# Wind_Speed(mph)      0
# Precipitation(in)    0
# Weather_Condition    0
# Amenity              0
# Bump                 0
# Crossing             0
# Give_Way             0
# Junction             0
# No_Exit              0
# Railway              0
# Roundabout           0
# Station              0
# Stop                 0
# Traffic_Calming      0
# Traffic_Signal       0
# Turning_Loop         0
# dtype: int64

# %%
data.describe()
# Out:
#             Severity      Start_Lat      Start_Lng        End_Lat  \
# count  290475.000000  290475.000000  290475.000000  290475.000000
# mean        2.089364      35.873608     -95.096800      35.873885
# std         0.498765       5.683571      17.800189       5.683622
# min         1.000000      24.571999    -124.497470      24.574326
# 25%         2.000000      32.271417    -117.767164      32.271776
# 50%         2.000000      35.717348     -86.789530      35.717882
# 75%         2.000000      40.080987     -80.336257      40.080493
# max         4.000000      48.993836     -67.484130      48.993995
#
#              End_Lng   Distance(mi)         Number  Temperature(F)  \
# count  290475.000000  290475.000000  290475.000000   290475.000000
# mean      -95.096287       0.247299    7966.484093       58.457972
# std        17.799606       1.141375   16100.126265       17.622883
# min      -124.497470       0.000000       1.000000      -89.000000
# 25%      -117.767545       0.000000    1149.000000       46.000000
# 50%       -86.789707       0.055000    3701.000000       59.000000
# 75%       -80.336393       0.169000    9244.500000       72.000000
# max       -67.484130     112.968000  961005.000000      111.000000
#
#        Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count   290475.000000    290475.000000      290475.000000
# mean         9.113594         7.179547           0.004135
# std          2.581299         5.664639           0.054130
# min          0.000000         0.000000           0.000000
# 25%         10.000000         3.000000           0.000000
# 50%         10.000000         7.000000           0.000000
# 75%         10.000000        10.000000           0.000000
# max        100.000000       211.000000          10.000000

# %% [markdown]
# # Top 10 cities by number of accident

# %%
accidents_by_cities = data['City'].value_counts()
accidents_by_cities
# Out:
# Miami             15837
# Orlando            6663
# Los Angeles        5882
# Charlotte          5813
# Houston            4918
#                   ...
# Rock Creek            1
# Luther                1
# Stamford              1
# Mattituck             1
# Pagosa Springs        1
# Name: City, Length: 6678, dtype: int64

# %%
accidents_by_cities[:10]
# Out:
# Miami          15837
# Orlando         6663
# Los Angeles     5882
# Charlotte       5813
# Houston         4918
# Raleigh         4759
# Tucson          4053
# Baton Rouge     3673
# Rochester       3351
# Austin          3180
# Name: City, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,3))
accidents_by_cities[:10].plot(kind='bar', color='g')
ax.set(title = 'Top 10 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
plt.show()

# %% [markdown]
# # Visualize distribution of accident severity

# %%
data['Severity'].value_counts()
# Out:
# 2    254412
# 4     12839
# 3     11752
# 1     11472
# Name: Severity, dtype: int64

# %%
sns.countplot(x='Severity', data=data)
plt.title('Distribution of Accident Severity')
plt.show()

# %% [markdown]
# # Visualize Accident Hotspots

# %%
# Plot geographical distribution using latitude and longitude
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Start_Lng', y='Start_Lat', data=data, alpha=0.1)
plt.title('Geographical Distribution of Accidents')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# # Visualize relationship between weather conditions and accident severity

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(x='Severity', y='Temperature(F)', data=data)
plt.title('Relationship between Temperature and Accident Severity')
plt.show()

# %%
f,ax=plt.subplots(2,3,figsize=(10,10))
ax[0,0] = data['Amenity'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0,0],colors=["cornflowerblue","salmon"])
ax[0,0].set_title("Amenity",fontweight ="bold")

ax[0,1] = data['Crossing'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0,1],colors=["cornflowerblue","salmon"])
ax[0,1].set_title("Crossing",fontweight ="bold")

ax[0,2] = data['Railway'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0,2],colors=["cornflowerblue","salmon"])
ax[0,2].set_title("Railway",fontweight ="bold")

ax[1,0] = data['Station'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1,0],colors=["cornflowerblue","salmon"])
ax[1,0].set_title("Station",fontweight ="bold")

ax[1,1] = data['Stop'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1,1],colors=["cornflowerblue","salmon"])
ax[1,1].set_title("Stop",fontweight ="bold")

ax[1,2] = data['Traffic_Signal'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1,2],colors=["cornflowerblue","salmon"])
ax[1,2].set_title("Traffic_Signal",fontweight ="bold")
plt.show()
